# %%
# ============================================================
# CÉLULA 1: IMPORTS E CONFIGURAÇÃO
# ============================================================
from models.captura_tela import CapturaTela
from models.automacao_cliques import AutomacaoOCR
import pyautogui
import time


print("="*60)
print("🤖 AUTOMAÇÃO ONESOURCE - PASSO A PASSO")
print("="*60)
print("\n✓ Bibliotecas carregadas")
# Out:
# ============================================================
# 🤖 AUTOMAÇÃO ONESOURCE - PASSO A PASSO
# ============================================================
#
# ✓ Bibliotecas carregadas

# %%
# ============================================================
# CÉLULA 2: NAVEGAR ATÉ A TELA DE IMPORT
# ============================================================
print("\n📍 ETAPA 1: Navegando de Módulos → Import")
print("-"*60)

# 1. Encontra e foca janela Módulos
captura = CapturaTela()
if not captura.encontrar_janela('Módulos'):
    raise Exception("❌ Janela Módulos não encontrada!")

captura.focar_janela()
print("✓ Janela Módulos focada")

# 2. Clica no menu desejado via OCR
auto_ocr_modulos = AutomacaoOCR('Módulos')
auto_ocr_modulos.clicar_menu_modulos('Import') # pode ser 'Import', 'Broker' ou 'In Out'


# 3. Aguarda janela Import abrir
print("\n⏳ Aguardando janela Import...")
if not captura.aguardar_janela('Import', timeout=10):
    raise Exception("❌ Janela Import não abriu!")

captura.focar_janela()
print("✓ Janela Import aberta e focada")

print("\n" + "="*60)
print("✅ ETAPA 1 CONCLUÍDA - Estamos na tela Import")
print("="*60)
# Out:
# 📍 ETAPA 1: Navegando de Módulos → Import
# ------------------------------------------------------------
# 🔍 Procurando janela com 'Módulos'...
# ✓ Janela encontrada: Módulos (Usuário: Natasha Lins Novaes / Último Acesso: 13/03/2026 16:58:53) - \\Remote
#   📍 Posição: (188, 18)
#   📏 Tamanho: 990x676
# ❌ Erro ao focar janela: Error code from Windows: 0 - A operação foi concluída com êxito.
# ✓ Janela Módulos focada
# 🔍 Procurando janela com 'Módulos'...
# ✓ Janela encontrada: Módulos (Usuário: Natasha Lins Novaes / Último Acesso: 13/03/2026 16:58:53) - \\Remote
#   📍 Posição: (188, 18)
#   📏 Tamanho: 990x676
# ❌ Erro ao focar janela: Error code from Windows: 0 - A operação foi concluída com êxito.
#
# 🧭 Clicando no módulo 'Import'...
# 🗑️  Cache limpo
# 🗑️  Cache OCR limpo
# 🔍 Processando OCR...
# 📸 Capturando região (50, 180, 260, 260)...
# ✓ Região capturada
# ✓ OCR processado - 23 elementos detectados
# ✓ Encontrado: 'Import' (confiança: 95%, similaridade: 100.0%)
# 🖱️  Clicando em 'Import' - tipo: double
# 🗑️  Cache limpo
# 🗑️  Cache OCR limpo
# ✓ Clique executado!
# ✅ Menu 'Import' clicado com sucesso!
#
# ⏳ Aguardando janela Import...
# ⏳ Aguardando janela com 'Import' aparecer...
# 🔍 Procurando janela com 'Import'...
# ❌ Janela com 'Import' não encontrada em 0.1s
#
# 📋 Janelas abertas:
#   - TF_FloatingLangBar_WndTitle - \\Remote
#   - Módulos (Usuário: Natasha Lins Novaes / Último Acesso: 13/03/2026 16:58:53) - \\Remote
#   - ● automation_new.ipynb - login_osgt - Visual Studio Code
#   - ▶️ SQL CODE - n8n[DEV] - Google Chrome
#   - Downloads e mais uma guia - Explorador de Arquivos
#   - Experiência de Entrada do Windows
#   - Giga VMS
#   - Program Manager
#
# 🔍 Procurando janela com 'Import'...
# ❌ Janela com 'Import' não encontrada em 0.1s
#
# 📋 Janelas abertas:
#   - TF_FloatingLangBar_WndTitle - \\Remote
#   - Módulos (Usuário: Natasha Lins Novaes / Último Acesso: 13/03/2026 16:58:53) - \\Remote
#   - ● automation_new.ipynb - login_osgt - Visual Studio Code
#   - ▶️ SQL CODE - n8n[DEV] - Google Chrome
#   - Downloads e mais uma guia - Explorador de Arquivos
#   - Experiência de Entrada do Windows
#   - Giga VMS
#   - Program Manager
#
# 🔍 Procurando janela com 'Import'...
# ❌ Janela com 'Import' não encontrada em 0.1s
#
# 📋 Janelas abertas:
#   - TF_FloatingLangBar_WndTitle - \\Remote
#   - Módulos (Usuário: Natasha Lins Novaes / Último Acesso: 13/03/2026 16:58:53) - \\Remote
#   - ● automation_new.ipynb - login_osgt - Visual Studio Code
#   - ▶️ SQL CODE - n8n[DEV] - Google Chrome
#   - Downloads e mais uma guia - Explorador de Arquivos
#   - Experiência de Entrada do Windows
#   - Giga VMS
#   - Program Manager
#
# 🔍 Procurando janela com 'Import'...
# ❌ Janela com 'Import' não encontrada em 0.1s
#
# 📋 Janelas abertas:
#   - TF_FloatingLangBar_WndTitle - \\Remote
#   - Módulos (Usuário: Natasha Lins Novaes / Último Acesso: 13/03/2026 16:58:53) - \\Remote
#   - ● automation_new.ipynb - login_osgt - Visual Studio Code
#   - ▶️ SQL CODE - n8n[DEV] - Google Chrome
#   - Downloads e mais uma guia - Explorador de Arquivos
#   - Experiência de Entrada do Windows
#   - Giga VMS
#   - Program Manager
#
# 🔍 Procurando janela com 'Import'...
# ❌ Janela com 'Import' não encontrada em 0.1s
#
# 📋 Janelas abertas:
#   - TF_FloatingLangBar_WndTitle - \\Remote
#   - Módulos (Usuário: Natasha Lins Novaes / Último Acesso: 13/03/2026 16:58:53) - \\Remote
#   - ● automation_new.ipynb - login_osgt - Visual Studio Code
#   - ▶️ SQL CODE - n8n[DEV] - Google Chrome
#   - Downloads e mais uma guia - Explorador de Arquivos
#   - Experiência de Entrada do Windows
#   - Giga VMS
#   - Program Manager
#
# 🔍 Procurando janela com 'Import'...
# ✓ Janela encontrada: ONESOURCE GLOBAL TRADE - Import ( Versão: 25.4 / Conexão: BorgWarner - PROD / Usuário: Natasha Lins Novaes / Grupo: Adm_IS_Suporte (Modulo de acesso ao ImportS - \\Remote
#   📍 Posição: (0, 0)
#   📏 Tamanho: 1366x720
# ✓ Janela 'Import' apareceu!
# ✓ Janela focada
# ✓ Janela Import aberta e focada
#
# ============================================================
# ✅ ETAPA 1 CONCLUÍDA - Estamos na tela Import
# ============================================================

# %%
# ============================================================
# CÉLULA 3: INICIALIZAR OCR NA TELA IMPORT
# ============================================================
print("\n📍 ETAPA 2: Inicializando OCR na tela Import")
print("-"*60)

# Cria instância do OCR apontando para janela Import
auto_ocr = AutomacaoOCR('Import')

print("✓ OCR inicializado e pronto para uso")
print("\n" + "="*60)
print("✅ ETAPA 2 CONCLUÍDA")
print("="*60)
# Out:
# 📍 ETAPA 2: Inicializando OCR na tela Import
# ------------------------------------------------------------
# 🔍 Procurando janela com 'Import'...
# ✓ Janela encontrada: ONESOURCE GLOBAL TRADE - Import ( Versão: 25.4 / Conexão: BorgWarner - PROD / Usuário: Natasha Lins Novaes / Grupo: Adm_IS_Suporte (Modulo de acesso ao ImportS - \\Remote
#   📍 Posição: (0, 0)
#   📏 Tamanho: 1366x720
# ✓ Janela focada
# ✓ OCR inicializado e pronto para uso
#
# ============================================================
# ✅ ETAPA 2 CONCLUÍDA
# ============================================================

# %%
# ============================================================
# CÉLULA 4: LISTAR TODOS OS TEXTOS DETECTADOS (DEBUG)
# ============================================================
print("\n📍 ETAPA 3: Listando textos detectados pelo OCR")
print("-"*60)

# Lista todos os textos que o OCR consegue ver
textos = auto_ocr.listar_todos_textos(confianca_minima=30)

print(f"\n✓ Total de {len(textos)} textos detectados")
print("\n" + "="*60)
print("✅ ETAPA 3 CONCLUÍDA")
print("="*60)
# Out:
# 📍 ETAPA 3: Listando textos detectados pelo OCR
# ------------------------------------------------------------
#
# ============================================================
# 📋 TODOS OS TEXTOS DETECTADOS:
# ============================================================
# 🔍 Processando OCR...
# 📸 Capturando screenshot...
# ✓ Screenshot capturado
# ✓ OCR processado - 178 elementos detectados
# ✓ 'ONESOURCE' (confiança: 79%)
# ✓ 'GLOBAL' (confiança: 96%)
# ✓ 'TRADE' (confiança: 91%)
# ✓ '-' (confiança: 91%)
# ✓ 'Import' (confiança: 92%)
# ✓ '(' (confiança: 92%)
# ✓ 'Versão:' (confiança: 96%)
# ✓ '25.4' (confiança: 93%)
# ✓ '/' (confiança: 93%)
# ✓ 'Conexão:' (confiança: 93%)
# ✓ 'BorgWarner' (confiança: 64%)
# ✓ '-' (confiança: 92%)
# ✓ 'PROD' (confiança: 89%)
# ✓ '/' (confiança: 89%)
# ✓ 'Usuário:' (confiança: 94%)
# ✓ 'Natasha' (confiança: 96%)
# ✓ 'Lins' (confiança: 96%)
# ✓ 'Novaes' (confiança: 93%)
# ✓ '/' (confiança: 93%)
# ✓ 'Grupo:' (confiança: 96%)
# ✓ 'Adm' (confiança: 93%)
# ✓ 'IS' (confiança: 90%)
# ✓ 'Suporte' (confiança: 90%)
# ✓ '(Modulo' (confiança: 96%)
# ✓ 'de' (confiança: 95%)
# ✓ 'acesso' (confiança: 89%)
# ✓ 'ao' (confiança: 83%)
# ✓ 'PT' (confiança: 95%)
# ✓ 'Portuguese' (confiança: 92%)
# ✓ '(Brazil)' (confiança: 46%)
# ✓ 'Ordens' (confiança: 85%)
# ✓ 'de' (confiança: 96%)
# ✓ 'Importação' (confiança: 57%)
# ✓ 'Processos' (confiança: 90%)
# ✓ 'de' (confiança: 96%)
# ✓ 'Importação' (confiança: 83%)
# ✓ 'Estatísticas' (confiança: 93%)
# ✓ '/' (confiança: 92%)
# ✓ 'Relstórios' (confiança: 48%)
# ✓ 'Cadastros' (confiança: 81%)
# ✓ 'Configurações' (confiança: 84%)
# ✓ 'Integrador' (confiança: 83%)
# ✓ 'Dados' (confiança: 89%)
# ✓ 'Mestres' (confiança: 86%)
# ✓ 'Ajuda' (confiança: 86%)
# ✓ 'Windows' (confiança: 75%)
# ✓ 'VE' (confiança: 38%)
# ✓ '=' (confiança: 86%)
# ✓ 'B' (confiança: 73%)
# ✓ 'custos' (confiança: 87%)
# ✓ '[Z' (confiança: 57%)
# ✓ 'Licenças' (confiança: 87%)
# ✓ 'My' (confiança: 52%)
# ✓ 'Remoções' (confiança: 83%)
# ✓ '[7]' (confiança: 64%)
# ✓ 'g' (confiança: 68%)
# ✓ '[4]' (confiança: 50%)
# ✓ 'Ordens' (confiança: 89%)
# ✓ 'checkOrdens' (confiança: 38%)
# ✓ '|' (confiança: 93%)
# ✓ 'Processos' (confiança: 66%)
# ✓ 'Faturas' (confiança: 53%)
# ✓ 'Conhecimentos' (confiança: 53%)
# ✓ 'Check' (confiança: 87%)
# ✓ 'Processos' (confiança: 95%)
# ✓ '|' (confiança: 95%)
# ✓ 'Pagamentos' (confiança: 85%)
# ✓ '|' (confiança: 96%)
# ✓ '[E' (confiança: 59%)
# ✓ 'Deckrações' (confiança: 61%)
# ✓ '|' (confiança: 95%)
# ✓ 'fig' (confiança: 48%)
# ✓ 'Recebimentos' (confiança: 85%)
# ✓ '|' (confiança: 85%)
# ✓ 'Singk' (confiança: 39%)
# ✓ 'Window' (confiança: 39%)
# ✓ '|' (confiança: 86%)
# ✓ '|' (confiança: 89%)
# ✓ 'Cocipt' (confiança: 68%)
# ✓ '|' (confiança: 96%)
# ✓ 'Mensagens' (confiança: 95%)
# ✓ '|' (confiança: 96%)
# ✓ 'Tracking' (confiança: 85%)
# ✓ '|' (confiança: 92%)
# ✓ '|' (confiança: 96%)
# ✓ 'Retorno' (confiança: 62%)
# ✓ 'Siscarga' (confiança: 88%)
# ✓ 'THOMSON' (confiança: 95%)
# ✓ 'REUTERS' (confiança: 96%)
# ✓ 'ONESOURCE' (confiança: 75%)
# ✓ 'Import' (confiança: 64%)
# ✓ 'NUM]' (confiança: 36%)
# ============================================================
# Total: 92 textos
# ============================================================
#
#
# ✓ Total de 92 textos detectados
#
# ============================================================
# ✅ ETAPA 3 CONCLUÍDA
# ============================================================

# %%
# ============================================================
# CÉLULA 5: CRIAR MAPA VISUAL (OPCIONAL)
# ============================================================
print("\n📍 ETAPA 4: Criando mapa visual do OCR")
print("-"*60)

# Cria imagem com retângulos vermelhos em todos os textos
auto_ocr.criar_mapa_visual('debug_import_ocr.png')

print("\n✓ Arquivo 'debug_import_ocr.png' salvo")
print("💡 Abra este arquivo para ver o que o OCR detectou")
print("\n" + "="*60)
print("✅ ETAPA 4 CONCLUÍDA")
print("="*60)
# Out:
# 📍 ETAPA 4: Criando mapa visual do OCR
# ------------------------------------------------------------
# 🎨 Criando mapa visual do OCR...
# 🔍 Processando OCR...
# 📸 Capturando screenshot...
# ✓ Screenshot capturado
# ✓ OCR processado - 178 elementos detectados
# ✓ Mapa visual salvo: debug_import_ocr.png
#
# ✓ Arquivo 'debug_import_ocr.png' salvo
# 💡 Abra este arquivo para ver o que o OCR detectou
#
# ============================================================
# ✅ ETAPA 4 CONCLUÍDA
# ============================================================

# %%
# ============================================================
# CÉLULA 6: CLICAR EM BOTÃO DA TOOLBAR (EXEMPLO: FATURAS)
# ============================================================
print("\n📍 ETAPA 5: Clicando no botão 'Faturas'")
print("-"*60)

#auto_ocr.limpar_cache_ocr()
# Tenta clicar usando OCR
sucesso = auto_ocr.clicar_botao_toolbar('Faturas', pausar=2)

if sucesso:
    print("\n✓ Clique em 'Faturas' executado com sucesso!")
else:
    auto_ocr.listar_todos_textos(
    confianca_minima=10
    )
    print("\n⚠️  OCR não encontrou, tentando coordenadas fixas...")
    # Fallback: usa coordenadas fixas
    x, y = captura.obter_posicao_absoluta(262, 70)
    pyautogui.click(x, y)
    time.sleep(2)
    print("✓ Clique executado com coordenadas fixas")

print("\n" + "="*60)
print("✅ ETAPA 5 CONCLUÍDA")
print("="*60)
# Out:
# 📍 ETAPA 5: Clicando no botão 'Faturas'
# ------------------------------------------------------------
#
# 🔘 Clicando no botão: 'Faturas'
# 🗑️  Cache limpo
# 🗑️  Cache OCR limpo
# 🗑️  Cache limpo
# 🗑️  Cache OCR limpo
# 🔍 Processando OCR...
# 📸 Capturando região (0, 60, 1366, 120)...
# ✓ Região capturada
# ✓ OCR processado - 69 elementos detectados
# ✓ Encontrado: 'Feturas' (confiança: 50%, similaridade: 85.7%)
# 🖱️  Clicando em 'Feturas' - tipo: single
# 🗑️  Cache limpo
# 🗑️  Cache OCR limpo
# ✓ Clique executado!
#
# ✓ Clique em 'Faturas' executado com sucesso!
#
# ============================================================
# ✅ ETAPA 5 CONCLUÍDA
# ============================================================

# %%
# ============================================================
# CÉLULA 8: CLICAR NO BOTÃO + (NOVO)
# ============================================================
time.sleep(5)  # Pausa para garantir que a tela esteja pronta
print("\n📍 ETAPA 8: Clicando no botão '+'")
print("-"*60)

# Clica no botão + da janela interna
sucesso = auto_ocr.clicar_botao_mais_janela_interna(pausar=2)

if sucesso:
    print("\n✓ Botão '+' clicado com sucesso!")

    # Captura tela após clicar (opcional)
    #auto_ocr.captura.capturar(salvar=True, nome_arquivo='04_apos_clicar_mais.png')
else:
    print("\n❌ Falha ao clicar no botão '+'")

print("\n" + "="*60)
print("✅ ETAPA 8 CONCLUÍDA")
print("="*60)
# Out:
# 📍 ETAPA 8: Clicando no botão '+'
# ------------------------------------------------------------
#
# ➕ Clicando no botão '+' da janela interna...
# 🔍 Tentando localizar botão '+' via OCR...
# 🔍 Processando OCR...
# 📸 Capturando região (230, 130, 100, 50)...
# ✓ Região capturada
# ✓ OCR processado - 8 elementos detectados
# ❌ Texto '+' não encontrado
# ⚠️  OCR não encontrou, usando coordenadas fixas...
# 🖱️  Clicando em (263, 150)...
# 🗑️  Cache limpo
# 🗑️  Cache OCR limpo
# ✓ Clique no botão '+' executado!
#
# ✓ Botão '+' clicado com sucesso!
#
# ============================================================
# ✅ ETAPA 8 CONCLUÍDA
# ============================================================

# %%
# ============================================================
# CÉLULA 9: CLICAR NO MENU COMPOSIÇÃO PARA EDITAR OS ITENS
# # ============================================================
time.sleep(5)

print("\n📍 ETAPA 9: Clicando no menu COMPOSIÇÃO ")
print("-"*60)

# Clica no menu composição da janela interna
sucesso = auto_ocr.clicar_menu_composicao_janela_interna(pausar=2)

if sucesso:
    print("\n✓ Menu 'COMPOSIÇÃO' clicado com sucesso!")

    # Captura tela após clicar (opcional)
    #auto_ocr.captura.capturar(salvar=True, nome_arquivo='04_apos_clicar_composicao.png')
else:
    print("\n❌ Falha ao clicar no menu 'COMPOSIÇÃO'")

print("\n" + "="*60)
print("✅ ETAPA 9 CONCLUÍDA")
print("="*60)
# Out:
# 📍 ETAPA 9: Clicando no menu COMPOSIÇÃO
# ------------------------------------------------------------
#
# 📋 Clicando no menu COMPOSIÇÃO da janela interna...
# 🔍 Tentando localizar menu 'COMPOSIÇÃO' via OCR...
# 🔍 Processando OCR...
# 📸 Capturando região (200, 120, 700, 80)...
# ✓ Região capturada
# ✓ OCR processado - 34 elementos detectados
# ❌ Texto 'COMPOSIÇÃO' não encontrado
# ⚠️  OCR não encontrou, usando coordenadas fixas...
# 🖱️  Clicando em (601, 150)...
# 🗑️  Cache limpo
# 🗑️  Cache OCR limpo
# ✓ Clique no menu 'COMPOSIÇÃO' executado!
#
# ✓ Menu 'COMPOSIÇÃO' clicado com sucesso!
#
# ============================================================
# ✅ ETAPA 9 CONCLUÍDA
# ============================================================

# %%
# ============================================================
# CÉLULA 10: CLICAR NO MENU COMPOSIÇÃO PARA EDITAR OS ITENS
# # ============================================================
time.sleep(5)

print("\n📍 ETAPA 10: Clicando no botão ADIÇÃO do menu composição ")
print("-"*60)

# Clica no botão ADIÇÃO do menu composição da janela interna
sucesso = auto_ocr.clicar_mais_composicao_janela_interna(pausar=2)

if sucesso:
    print("\n✓ Botão 'ADIÇÃO' do menu 'COMPOSIÇÃO' clicado com sucesso!")

    # Captura tela após clicar (opcional)
    #auto_ocr.captura.capturar(salvar=True, nome_arquivo='04_apos_clicar_composicao.png')
else:
    print("\n❌ Falha ao clicar no botão 'ADIÇÃO' do menu 'COMPOSIÇÃO'")

print("\n" + "="*60)
print("✅ ETAPA 10 CONCLUÍDA")
print("="*60)

time.sleep(2)
##################
#Separação para chamar o script load_invoice.py para processar os itens e depois retornar o resultado para o N8N.
##################
# Out:
# 📍 ETAPA 10: Clicando no botão ADIÇÃO do menu composição
# ------------------------------------------------------------
#
# 📋 Clicando no menu COMPOSIÇÃO da janela interna...
# 🖱️  Clicando em (1102, 208)...
# 🗑️  Cache limpo
# 🗑️  Cache OCR limpo
# ✓ Clique no menu 'COMPOSIÇÃO' executado!
#
# ✓ Botão 'ADIÇÃO' do menu 'COMPOSIÇÃO' clicado com sucesso!
#
# ============================================================
# ✅ ETAPA 10 CONCLUÍDA
# ============================================================

# %%
from models.automacao_cliques import AutomacaoOCR
import pyperclip

auto_ocr = AutomacaoOCR('ONESOURCE GLOBAL TRADE - Import')

valor_teste_ordem = "123456789"
auto_ocr.preencher_campo_clipboard(
    342,  # coordenadas do Núm. Ordem
    494,
    valor_teste_ordem,
    pausar=1
)

print("Clipboard após Núm. Ordem:", pyperclip.paste())
# Out:
# 🔍 Procurando janela com 'ONESOURCE GLOBAL TRADE - Import'...
# ✓ Janela encontrada: ONESOURCE GLOBAL TRADE - Import ( Versão: 25.4 / Conexão: BorgWarner - PROD / Usuário: Natasha Lins Novaes / Grupo: Adm_IS_Suporte (Modulo de acesso ao ImportS - \\Remote
#   📍 Posição: (0, 0)
#   📏 Tamanho: 1366x720
# ✓ Janela focada
#
# 📋 Preenchendo campo via clipboard com '123456789'...
# 🗑️  Cache limpo
# 🗑️  Cache OCR limpo
# ✓ Campo preenchido com '123456789'!
# Clipboard após Núm. Ordem: 123456789

# %%
# ============================================================
# CHAMADA DO load_invoice.py
# ============================================================
import subprocess, sys
print("\n📍 CHAMANDO load_invoice.py...")
print("-"*60)

resultado = subprocess.run(
    [sys.executable, "load_invoice.py"],
    capture_output=False,  # False = mostra output em tempo real no terminal
    text=True
)

if resultado.returncode != 0:
    print("❌ load_invoice.py falhou! Abortando logoff.")
    raise Exception("Falha no load_invoice.py")

print("✅ load_invoice.py concluído com sucesso!")
# Out:
# 📍 CHAMANDO load_invoice.py...
# ------------------------------------------------------------

# %%
#auto_ocr = AutomacaoOCR('Import')
#qs = auto_ocr.ler_quantidades_grade_qualidade_baixa(confianca_minima=10)
#print("\nResultado final:", qs)
#print("Soma:", sum(qs))

# %%
# ============================================================
# CÉLULA 11: MENU BARRA - FECHAMENTO OSGT (EXEMPLO: WINDOWS    )
# ============================================================

print("\n📍 ETAPA 5: Clicando no botão 'Windows'")
print("-"*60)
time.sleep(2)
# Tenta clicar usando OCR
sucesso = auto_ocr.clicar_menu_barra('Windows', pausar=2)

if sucesso:
    print("\n✓ Clique em 'Windows' executado com sucesso!")
    time.sleep(2)
else:
    print("\n⚠️  OCR não encontrou, tentando coordenadas fixas...")
    # Fallback: usa coordenadas fixas
    x, y = captura.obter_posicao_absoluta(886, 34)
    pyautogui.click(x, y)
    time.sleep(2)
    print("✓ Clique executado com coordenadas fixas")

# %%
# ============================================================
# CÉLULA 12: MENU BARRA - SAIR DO SISTEMA - 
# ============================================================
#sucesso = auto_ocr.clicar_em_texto('Sair do Sistema', pausar=1.0)
x, y = captura.obter_posicao_absoluta(926, 298)
pyautogui.click(x, y)
time.sleep(2)
# COORDENADAS CONFIRMAÇÃO - REALMENTE QUER SAIR DO SISTEMA - BOTÃO SIM (641, 401)
x, y = captura.obter_posicao_absoluta(641, 401)
pyautogui.click(x, y)
time.sleep(2)
# COORDENADAS BOTÃO 'NÃO' - CAIXA DIALOGO ATENÇÃO - SALVAR RASCUNHO DA FATURA - BOTÃO NÃO(682, 399)
x, y = captura.obter_posicao_absoluta(682, 399)
pyautogui.click(x, y)
time.sleep(2)

# %%
auto_ocr = AutomacaoOCR('ONESOURCE GLOBAL TRADE - Import')
if auto_ocr.detectar_popup_nenhum_item():
    print(f" POPup ENCONTRADO.")
    auto_ocr.fechar_popup_nenhum_item(pausar=1.0)
else:
    print(f" POPup NÃO ENCONTRADO.")
